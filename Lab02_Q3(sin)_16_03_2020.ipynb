# %% [markdown]
# <a href="https://colab.research.google.com/github/selinyeltekin/MyRepo/blob/master/Lab02_Q3(sin)_16_03_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plot

def sin_approx(x, n):
    val = 0
    for m in range(n):
        val += (-1)**m * x**(2 * m + 1) / factorial(2 * m + 1)
        
    return val

def factorial(n):
  if n<2:
        return 1
  else:
        return n*factorial(n-1)

# Get x values of the sin wave
time = np.arange(-3, 3, 0.1);

#Amplitude of the sin wave is sine of a variable like time
amplitude1 = np.sin(time)

#Amplitude of the sin wave with Tylor Series
amplitude2 = []
for x in time:
  help = 0
  for n in range(2):
    help = help + ((-1)**n)*((x**(2*n+1))/factorial(2*n+1))
  amplitude2.append(help)

#Guidelines
#Plot a sine wave using time and amplitude obtained for the sine wave
plot.plot(time, amplitude1)
plot.plot(time, amplitude2)

#Give a title for the sine wave plot
plot.title('Sine wave')

#Give x axis label for the sine wave plot
plot.xlabel('Time')
#Give y axis label for the sine wave plot
plot.ylabel('Amplitude1=sin(time)')
plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()

#Display the sine wave
plot.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#amplitude3 shows the difference between amplitude2 and amplitude
amplitude3 = amplitude2 - amplitude1
plot.plot(time, amplitude3)
#Give a title for the sine wave plot
plot.title('Difference between numpy sin and Tylor approximation')

#Give x axis label for the sine wave plot
plot.xlabel('Time')
#Give y axis label for the sine wave plot
plot.ylabel('Amplitude')
plot.grid(True, which='both')
plot.axhline(y=0, color='k')
plot.show()
plot.show
# Out:
# <function matplotlib.pyplot.show>
